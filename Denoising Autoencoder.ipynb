# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow.keras.preprocessing import image
from sklearn.model_selection import train_test_split

# Ensure TensorFlow is using GPU
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# Define the dataset path
dataset_path = '/kaggle/input/human-images-dataset-men-and-women/'

# Handle possible subdirectories and ensure correct image file types are loaded
image_files = []
for root, _, files in os.walk(dataset_path):
    for file in files:
        if file.endswith('.jpg') or file.endswith('.png'):
            image_files.append(os.path.join(root, file))

print(f"Found {len(image_files)} image files.")  # Print number of images found

# Check the first few image paths
print(image_files[:5])  # Print first 5 image file names to ensure correct files are being loaded

# Load and preprocess the images
img_size = 128  # Resize all images to 128x128
images = []

for img_path in image_files:
    try:
        img = image.load_img(img_path, target_size=(img_size, img_size), color_mode='rgb')
        img_array = image.img_to_array(img)
        img_array = img_array.astype('float32') / 255.  # Normalize to [0, 1]
        images.append(img_array)
    except Exception as e:
        print(f"Error loading image {img_path}: {e}")

images = np.array(images)

# Check if images are loaded successfully
if images.shape[0] == 0:
    print("No images were loaded. Check your dataset path or image files.")
else:
    print(f"Loaded {images.shape[0]} images.")

# Flatten images to 1D vectors
images_flat = images.reshape((len(images), -1))

# Split into training and test sets
x_train, x_test = train_test_split(images_flat, test_size=0.2, random_state=42)

# Add noise to the images
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# Clip the values to stay within [0, 1]
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# Define the autoencoder architecture
input_img = tf.keras.Input(shape=(img_size * img_size * 3,))  # For RGB images

# Encoder
encoded = tf.keras.layers.Dense(512, activation='relu')(input_img)
encoded = tf.keras.layers.Dense(256, activation='relu')(encoded)
encoded = tf.keras.layers.Dense(128, activation='relu')(encoded)
encoded = tf.keras.layers.Dense(64, activation='relu')(encoded)

# Decoder
decoded = tf.keras.layers.Dense(128, activation='relu')(encoded)
decoded = tf.keras.layers.Dense(256, activation='relu')(decoded)
decoded = tf.keras.layers.Dense(512, activation='relu')(decoded)
decoded = tf.keras.layers.Dense(img_size * img_size * 3, activation='sigmoid')(decoded)  # Output shape (128x128x3)

# Create and compile the model
autoencoder = tf.keras.Model(input_img, decoded)

# Specify GPU usage explicitly (for TensorFlow to ensure GPU acceleration)
with tf.device('/GPU:0'):  # Use the first GPU device (adjust as needed)
    autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the model
autoencoder.fit(x_train_noisy, x_train,
                epochs=200,
                batch_size=32,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))

# Predict denoised images
decoded_imgs = autoencoder.predict(x_test_noisy)

# Visualize some of the original, noisy, and reconstructed images
n = 10  # Number of images to display
plt.figure(figsize=(20, 6))
for i in range(n):
    # Display original
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test[i].reshape(img_size, img_size, 3))
    plt.axis('off')

    # Display noisy image
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(x_test_noisy[i].reshape(img_size, img_size, 3))
    plt.axis('off')

    # Display reconstruction
    ax = plt.subplot(3, n, i + 1 + 2 * n)
    plt.imshow(decoded_imgs[i].reshape(img_size, img_size, 3))
    plt.axis('off')
# Out:
# Num GPUs Available:  1
# Found 1668 image files.
# ['/kaggle/input/human-images-dataset-men-and-women/gender_dataset/men/623.jpg', '/kaggle/input/human-images-dataset-men-and-women/gender_dataset/men/764.jpg', '/kaggle/input/human-images-dataset-men-and-women/gender_dataset/men/771.jpg', '/kaggle/input/human-images-dataset-men-and-women/gender_dataset/men/208.jpg', '/kaggle/input/human-images-dataset-men-and-women/gender_dataset/men/820.jpg']
# Loaded 1668 images.
# Epoch 1/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.6846 - val_loss: 0.6447
# Epoch 2/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6481 - val_loss: 0.6367
# Epoch 3/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6361 - val_loss: 0.6325
# Epoch 4/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6249 - val_loss: 0.6293
# Epoch 5/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6131 - val_loss: 0.6322
# Epoch 6/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6088 - val_loss: 0.6205
# Epoch 7/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5982 - val_loss: 0.6203
# Epoch 8/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5993 - val_loss: 0.6126
# Epoch 9/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5889 - val_loss: 0.6175
# Epoch 10/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5864 - val_loss: 0.6140
# Epoch 11/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5854 - val_loss: 0.6097
# Epoch 12/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5824 - val_loss: 0.6094
# Epoch 13/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5748 - val_loss: 0.6018
# Epoch 14/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5772 - val_loss: 0.6010
# Epoch 15/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.5709 - val_loss: 0.5975
# Epoch 16/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5666 - val_loss: 0.5961
# Epoch 17/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5682 - val_loss: 0.6039
# Epoch 18/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5638 - val_loss: 0.5915
# Epoch 19/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5659 - val_loss: 0.5948
# Epoch 20/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5625 - val_loss: 0.5902
# Epoch 21/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5573 - val_loss: 0.5904
# Epoch 22/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5613 - val_loss: 0.5919
# Epoch 23/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5575 - val_loss: 0.5904
# Epoch 24/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5570 - val_loss: 0.5905
# Epoch 25/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5515 - val_loss: 0.5900
# Epoch 26/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.5567 - val_loss: 0.5925
# Epoch 27/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.5521 - val_loss: 0.5925
# Epoch 28/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5575 - val_loss: 0.5888
# Epoch 29/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5525 - val_loss: 0.5884
# Epoch 30/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5528 - val_loss: 0.5884
# Epoch 31/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5492 - val_loss: 0.5916
# Epoch 32/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5470 - val_loss: 0.5878
# Epoch 33/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5469 - val_loss: 0.5886
# Epoch 34/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5453 - val_loss: 0.5888
# Epoch 35/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5434 - val_loss: 0.5902
# Epoch 36/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5440 - val_loss: 0.5896
# Epoch 37/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5364 - val_loss: 0.5926
# Epoch 38/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5450 - val_loss: 0.5923
# Epoch 39/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5405 - val_loss: 0.5918
# Epoch 40/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5393 - val_loss: 0.5945
# Epoch 41/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5380 - val_loss: 0.5917
# Epoch 42/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5363 - val_loss: 0.5953
# Epoch 43/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5341 - val_loss: 0.5922
# Epoch 44/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5357 - val_loss: 0.5927
# Epoch 45/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5339 - val_loss: 0.5961
# Epoch 46/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5348 - val_loss: 0.5962
# Epoch 47/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5367 - val_loss: 0.6006
# Epoch 48/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5340 - val_loss: 0.5955
# Epoch 49/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5271 - val_loss: 0.5968
# Epoch 50/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5325 - val_loss: 0.5969
# Epoch 51/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5218 - val_loss: 0.5969
# Epoch 52/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5331 - val_loss: 0.5981
# Epoch 53/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5267 - val_loss: 0.6029
# Epoch 54/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5352 - val_loss: 0.5998
# Epoch 55/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5255 - val_loss: 0.5971
# Epoch 56/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5211 - val_loss: 0.5989
# Epoch 57/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5239 - val_loss: 0.6043
# Epoch 58/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5230 - val_loss: 0.5984
# Epoch 59/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5211 - val_loss: 0.6006
# Epoch 60/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5208 - val_loss: 0.6004
# Epoch 61/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5162 - val_loss: 0.6013
# Epoch 62/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5194 - val_loss: 0.6004
# Epoch 63/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5153 - val_loss: 0.6009
# Epoch 64/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5166 - val_loss: 0.6046
# Epoch 65/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5160 - val_loss: 0.6037
# Epoch 66/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5171 - val_loss: 0.6032
# Epoch 67/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5142 - val_loss: 0.6041
# Epoch 68/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5146 - val_loss: 0.6042
# Epoch 69/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5121 - val_loss: 0.6058
# Epoch 70/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5114 - val_loss: 0.6047
# Epoch 71/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5153 - val_loss: 0.6064
# Epoch 72/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5110 - val_loss: 0.6081
# Epoch 73/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5149 - val_loss: 0.6058
# Epoch 74/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5166 - val_loss: 0.6063
# Epoch 75/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5151 - val_loss: 0.6072
# Epoch 76/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5086 - val_loss: 0.6105
# Epoch 77/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5128 - val_loss: 0.6173
# Epoch 78/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5146 - val_loss: 0.6072
# Epoch 79/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5136 - val_loss: 0.6065
# Epoch 80/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5102 - val_loss: 0.6077
# Epoch 81/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5062 - val_loss: 0.6075
# Epoch 82/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5065 - val_loss: 0.6088
# Epoch 83/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5087 - val_loss: 0.6112
# Epoch 84/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5130 - val_loss: 0.6084
# Epoch 85/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5088 - val_loss: 0.6114
# Epoch 86/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5091 - val_loss: 0.6087
# Epoch 87/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5120 - val_loss: 0.6110
# Epoch 88/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5061 - val_loss: 0.6118
# Epoch 89/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5086 - val_loss: 0.6095
# Epoch 90/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5083 - val_loss: 0.6104
# Epoch 91/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.5005 - val_loss: 0.6105
# Epoch 92/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5092 - val_loss: 0.6098
# Epoch 93/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5056 - val_loss: 0.6135
# Epoch 94/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5038 - val_loss: 0.6118
# Epoch 95/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5041 - val_loss: 0.6117
# Epoch 96/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5062 - val_loss: 0.6112
# Epoch 97/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5023 - val_loss: 0.6125
# Epoch 98/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5024 - val_loss: 0.6108
# Epoch 99/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5012 - val_loss: 0.6146
# Epoch 100/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5017 - val_loss: 0.6118
# Epoch 101/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5047 - val_loss: 0.6129
# Epoch 102/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5010 - val_loss: 0.6150
# Epoch 103/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4990 - val_loss: 0.6144
# Epoch 104/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5062 - val_loss: 0.6141
# Epoch 105/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5054 - val_loss: 0.6133
# Epoch 106/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5023 - val_loss: 0.6121
# Epoch 107/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5007 - val_loss: 0.6157
# Epoch 108/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4999 - val_loss: 0.6117
# Epoch 109/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5059 - val_loss: 0.6162
# Epoch 110/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5063 - val_loss: 0.6121
# Epoch 111/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5022 - val_loss: 0.6178
# Epoch 112/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5010 - val_loss: 0.6133
# Epoch 113/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5022 - val_loss: 0.6134
# Epoch 114/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5020 - val_loss: 0.6136
# Epoch 115/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4937 - val_loss: 0.6143
# Epoch 116/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5018 - val_loss: 0.6145
# Epoch 117/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5030 - val_loss: 0.6147
# Epoch 118/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5019 - val_loss: 0.6167
# Epoch 119/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4971 - val_loss: 0.6145
# Epoch 120/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4994 - val_loss: 0.6141
# Epoch 121/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5045 - val_loss: 0.6144
# Epoch 122/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5057 - val_loss: 0.6163
# Epoch 123/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4996 - val_loss: 0.6139
# Epoch 124/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5032 - val_loss: 0.6178
# Epoch 125/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5004 - val_loss: 0.6152
# Epoch 126/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5013 - val_loss: 0.6147
# Epoch 127/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5004 - val_loss: 0.6147
# Epoch 128/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4959 - val_loss: 0.6133
# Epoch 129/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4975 - val_loss: 0.6155
# Epoch 130/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4966 - val_loss: 0.6155
# Epoch 131/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4992 - val_loss: 0.6162
# Epoch 132/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4937 - val_loss: 0.6152
# Epoch 133/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4935 - val_loss: 0.6168
# Epoch 134/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4932 - val_loss: 0.6179
# Epoch 135/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4997 - val_loss: 0.6188
# Epoch 136/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4988 - val_loss: 0.6165
# Epoch 137/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4954 - val_loss: 0.6205
# Epoch 138/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4987 - val_loss: 0.6203
# Epoch 139/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4980 - val_loss: 0.6170
# Epoch 140/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5047 - val_loss: 0.6133
# Epoch 141/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5069 - val_loss: 0.6161
# Epoch 142/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4988 - val_loss: 0.6187
# Epoch 143/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5020 - val_loss: 0.6154
# Epoch 144/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5043 - val_loss: 0.6170
# Epoch 145/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5001 - val_loss: 0.6172
# Epoch 146/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5011 - val_loss: 0.6157
# Epoch 147/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4916 - val_loss: 0.6169
# Epoch 148/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5011 - val_loss: 0.6160
# Epoch 149/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4935 - val_loss: 0.6146
# Epoch 150/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4990 - val_loss: 0.6141
# Epoch 151/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4919 - val_loss: 0.6161
# Epoch 152/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4953 - val_loss: 0.6160
# Epoch 153/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4970 - val_loss: 0.6174
# Epoch 154/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4950 - val_loss: 0.6162
# Epoch 155/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4917 - val_loss: 0.6179
# Epoch 156/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4931 - val_loss: 0.6171
# Epoch 157/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4934 - val_loss: 0.6200
# Epoch 158/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4939 - val_loss: 0.6175
# Epoch 159/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4933 - val_loss: 0.6170
# Epoch 160/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4931 - val_loss: 0.6173
# Epoch 161/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4992 - val_loss: 0.6191
# Epoch 162/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4983 - val_loss: 0.6162
# Epoch 163/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5041 - val_loss: 0.6165
# Epoch 164/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4996 - val_loss: 0.6166
# Epoch 165/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4960 - val_loss: 0.6159
# Epoch 166/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4984 - val_loss: 0.6187
# Epoch 167/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5023 - val_loss: 0.6146
# Epoch 168/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4963 - val_loss: 0.6160
# Epoch 169/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4982 - val_loss: 0.6156
# Epoch 170/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4978 - val_loss: 0.6175
# Epoch 171/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4940 - val_loss: 0.6182
# Epoch 172/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4940 - val_loss: 0.6167
# Epoch 173/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4956 - val_loss: 0.6154
# Epoch 174/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5019 - val_loss: 0.6168
# Epoch 175/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4888 - val_loss: 0.6177
# Epoch 176/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4895 - val_loss: 0.6174
# Epoch 177/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4982 - val_loss: 0.6187
# Epoch 178/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4927 - val_loss: 0.6176
# Epoch 179/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4967 - val_loss: 0.6185
# Epoch 180/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4970 - val_loss: 0.6185
# Epoch 181/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4932 - val_loss: 0.6183
# Epoch 182/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4976 - val_loss: 0.6195
# Epoch 183/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4956 - val_loss: 0.6165
# Epoch 184/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4976 - val_loss: 0.6157
# Epoch 185/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4983 - val_loss: 0.6168
# Epoch 186/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5022 - val_loss: 0.6194
# Epoch 187/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5013 - val_loss: 0.6150
# Epoch 188/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5029 - val_loss: 0.6135
# Epoch 189/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4998 - val_loss: 0.6148
# Epoch 190/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4958 - val_loss: 0.6152
# Epoch 191/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5004 - val_loss: 0.6154
# Epoch 192/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4893 - val_loss: 0.6187
# Epoch 193/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4862 - val_loss: 0.6173
# Epoch 194/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4905 - val_loss: 0.6177
# Epoch 195/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4932 - val_loss: 0.6176
# Epoch 196/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4935 - val_loss: 0.6166
# Epoch 197/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4952 - val_loss: 0.6186
# Epoch 198/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4966 - val_loss: 0.6176
# Epoch 199/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4956 - val_loss: 0.6174
# Epoch 200/200
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4905 - val_loss: 0.6173
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
